# %%
import numpy as np
import matplotlib.pyplot as plt
import strawb
import strawb.sensors.minispec as minispec
import os

# %% [markdown]
# ## 1. Download the files from minispec module(5 devices) and pmtspec(1 devices) module ##

# %%
onc_downloader = strawb.ONCDownloader(showInfo=False)

filters = {'deviceCode': 'TUMMINISPECTROMETER001',
           'dateFrom': '2021-05-01T19:00:00.000Z',
           'dateTo': '2021-05-01T21:59:59.000Z',
           'extension': 'hdf5'}

# download in foreground
onc_downloader.download_file(filters=filters, allPages=True)
# Out:
# Download in directory: /Users/ruohanli/Documents/Programs/strawb_package/raw_module_data
# Obtained a list of 5 files to download.
#    Skipping "TUMMINISPECTROMETER001_20210501T000000.000Z-SDAQ-MINISPEC.hdf5": File already exists.
#    Skipping "TUMMINISPECTROMETER001_20210501T000000.000Z-SDAQ-MODULE.hdf5": File already exists.
#    Skipping "TUMMINISPECTROMETER001_20210501T190000.000Z-SDAQ-CAMERA.hdf5": File already exists.
#    Skipping "TUMMINISPECTROMETER001_20210501T200000.000Z-SDAQ-CAMERA.hdf5": File already exists.
#    Skipping "TUMMINISPECTROMETER001_20210501T210000.000Z-SDAQ-CAMERA.hdf5": File already exists.
# 0 files (0 Bytes) downloaded
# Total Download Time: 0.000 seconds

# %%
filters = {'deviceCode': 'TUMPMTSPECTROMETER001',
           'dateFrom': '2021-05-01T19:00:00.000Z',
           'dateTo': '2021-05-01T21:59:59.000Z',
           'extension': 'hdf5'}

# download in foreground
onc_downloader.download_file(filters=filters, allPages=True)
# Out:
# Download in directory: /Users/ruohanli/Documents/Programs/strawb_package/raw_module_data
# Obtained a list of 8 files to download.
#    Skipping "TUMPMTSPECTROMETER001_20210501T000000.000Z-SDAQ-MINISPEC.hdf5": File already exists.
#    Skipping "TUMPMTSPECTROMETER001_20210501T000000.000Z-SDAQ-MODULE.hdf5": File already exists.
#    Skipping "TUMPMTSPECTROMETER001_20210501T190000.000Z-SDAQ-CAMERA.hdf5": File already exists.
#    Skipping "TUMPMTSPECTROMETER001_20210501T190000.000Z-SDAQ-PMTSPEC.hdf5": File already exists.
#    Skipping "TUMPMTSPECTROMETER001_20210501T200000.000Z-SDAQ-PMTSPEC.hdf5": File already exists.
#    Skipping "TUMPMTSPECTROMETER001_20210501T200000.000Z-SDAQ-CAMERA.hdf5": File already exists.
#    Skipping "TUMPMTSPECTROMETER001_20210501T210000.000Z-SDAQ-PMTSPEC.hdf5": File already exists.
#    Skipping "TUMPMTSPECTROMETER001_20210501T210000.000Z-SDAQ-CAMERA.hdf5": File already exists.
# 0 files (0 Bytes) downloaded
# Total Download Time: 0.000 seconds

# %% [markdown]
# ## 2. test two condition of importing data from module##

# %%
#pmtspec file
pmt_file_name = "TUMPMTSPECTROMETER001_20210501T000000.000Z-SDAQ-MINISPEC.hdf5"
pmt_minispec_run = minispec.FileHandler(pmt_file_name)

print(pmt_minispec_run.start_time)
print(pmt_minispec_run.end_time)
print(pmt_minispec_run.module)
print(pmt_minispec_run.device_number)
print(pmt_minispec_run.data_array)
# Out:
# /Users/ruohanli/Documents/Programs/strawb_package/raw_module_data/TUMPMTSPECTROMETER001_20210501T000000.000Z-SDAQ-MINISPEC.hdf5
# PMTSPECTROMETER001
# 20210501T000000
# 2021-05-01 00:00:00
# 2021-05-01 23:58:59.218292
# PMTSPECTROMETER001
# 1
# [<strawb.sensors.minispec.file_handler.spectrum object at 0x7fb707c78310>]

# %%
#minispec file
minispec_file_name = 'TUMMINISPECTROMETER001_20210501T000000.000Z-SDAQ-MINISPEC.hdf5'
minispec_minispec_run = minispec.FileHandler(minispec_file_name)

print(minispec_minispec_run.start_time)
print(minispec_minispec_run.end_time)
print(minispec_minispec_run.module)
print(minispec_minispec_run.device_number)
print(minispec_minispec_run.data_array[0].CAL_ARR)
print(minispec_minispec_run.data_array[2].CAL_ARR)
print(minispec_minispec_run.data_array[4].CAL_ARR)
# Out:
# /Users/ruohanli/Documents/Programs/strawb_package/raw_module_data/TUMMINISPECTROMETER001_20210501T000000.000Z-SDAQ-MINISPEC.hdf5
# MINISPECTROMETER001
# 20210501T000000
# 2021-05-01 00:00:00
# 2021-05-02 00:00:00
# MINISPECTROMETER001
# 5
# [ 3.10534696e+02  2.70498577e+00 -1.35924145e-03 -5.14485001e-06
#  -1.68125526e-09  2.11549646e-11]
# [ 3.12871650e+02  2.69627793e+00 -1.20340938e-03 -6.66349141e-06
#   4.52566970e-09  1.21575386e-11]
# [ 3.07999186e+02  2.70214287e+00 -1.25434292e-03 -5.99610021e-06
#   1.18790575e-09  1.77112422e-11]

# %% [markdown]
# ## 3. test wavelength and darkcount calibration ##

# %%
print(pmt_minispec_run.if_wavecal)
wavelength_before = pmt_minispec_run.data_array[0].WAVELENGTH_ARR
#print(pmt_minispec_run.data_array[0].WAVELENGTH_ARR)
pmt_minispec_run.calculate_wavelength()
print(pmt_minispec_run.if_wavecal)
wavelength_after = pmt_minispec_run.data_array[0].WAVELENGTH_ARR
#print(pmt_minispec_run.data_array[0].WAVELENGTH_ARR)
wavelength_before-wavelength_after

# hint: you can also enter "wavelength_cal=True"or "darkcount_cal=True" to calibrate wavelength 
# at initialise the minispec_minispec_run. For example :
# minispec_minispec_run = minispec.FileHandler(minispec_file_name,wavelength_cal=True,)

# %%
print(pmt_minispec_run.if_darksub)
count_before = pmt_minispec_run.data_array[0].ADC_counts
#print(pmt_minispec_run.data_array[0].ADC_counts)
pmt_minispec_run.calibrate_adc_counts()
print(pmt_minispec_run.if_darksub)
count_after = pmt_minispec_run.data_array[0].ADC_counts
#print(pmt_minispec_run.data_array[0].ADC_counts)
wavelength_before-wavelength_after

# %% [markdown]
# ## 4. try to plot the spectrum ##

# %%
# simplest plot
# in principle there are three kind of possilbe x_data input, choose according your need
# raw data: pmt_minispec_run.data_array[0].ADC_counts
# dark data: pmt_minispec_run.data_array[0].ADC_counts_dark
# raw-dark data : pmt_minispec_run.data_array[0].ADC_counts_cal
select_pixel = 2
x_data = pmt_minispec_run.data_array[0].WAVELENGTH_ARR
y_data = (pmt_minispec_run.data_array[0].ADC_counts)[select_pixel,:]/pmt_minispec_run.data_array[0].exposure_time[select_pixel] #/1e6
plt.plot(x_data,y_data,'-',label="non-calibrated spectrum")
plt.xlabel("wavelength[nm]")
plt.xlabel("ADC account")
plt.title(pmt_file_name,y=1.2)
plt.rcParams['axes.titley'] = 1.2
plt.show()

# %% [markdown]
# ## 5. test combine multiple files ##

# %%
onc_downloader = strawb.ONCDownloader(showInfo=False)
filters = {'deviceCode': 'TUMPMTSPECTROMETER001',
           'dateFrom': '2021-05-02T00:00:00.000Z',
           'dateTo': '2021-05-02T23:59:59.000Z',
           'extension': 'hdf5'}

# download in foreground
onc_downloader.download_file(filters=filters, allPages=True)
# Out:
# Download in directory: /Users/ruohanli/Documents/Programs/strawb_package/raw_module_data
# Obtained a list of 52 files to download.
#    (1 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T000000.000Z-SDAQ-CAMERA.hdf5"
#    (2 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T000000.000Z-SDAQ-MINISPEC.hdf5"
#    (3 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T000000.000Z-SDAQ-PMTSPEC.hdf5"
#    (4 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T000000.000Z-SDAQ-MODULE.hdf5"
#    (5 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T010000.000Z-SDAQ-PMTSPEC.hdf5"
#    (6 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T010000.000Z-SDAQ-CAMERA.hdf5"
#    (7 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T020000.000Z-SDAQ-PMTSPEC.hdf5"
#    (8 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T020000.000Z-SDAQ-CAMERA.hdf5"
#    (9 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T030000.000Z-SDAQ-CAMERA.hdf5"
#    (10 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T030000.000Z-SDAQ-PMTSPEC.hdf5"
#    (11 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T030107.967Z-SDAQ-PMTSPEC.hdf5"
#    (12 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T030945.562Z-SDAQ-PMTSPEC.hdf5"
#    (13 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T040000.000Z-SDAQ-CAMERA.hdf5"
#    (14 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T040000.000Z-SDAQ-PMTSPEC.hdf5"
#    (15 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T050000.000Z-SDAQ-CAMERA.hdf5"
#    (16 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T050000.000Z-SDAQ-PMTSPEC.hdf5"
#    (17 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T060000.000Z-SDAQ-CAMERA.hdf5"
#    (18 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T060000.000Z-SDAQ-PMTSPEC.hdf5"
#    (19 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T070000.000Z-SDAQ-CAMERA.hdf5"
#    (20 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T070000.000Z-SDAQ-PMTSPEC.hdf5"
#    (21 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T080000.000Z-SDAQ-CAMERA.hdf5"
#    (22 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T080000.000Z-SDAQ-PMTSPEC.hdf5"
#    (23 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T090000.000Z-SDAQ-CAMERA.hdf5"
#    (24 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T090000.000Z-SDAQ-PMTSPEC.hdf5"
#    (25 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T100000.000Z-SDAQ-PMTSPEC.hdf5"
#    (26 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T100000.000Z-SDAQ-CAMERA.hdf5"
#    (27 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T110000.000Z-SDAQ-PMTSPEC.hdf5"
#    (28 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T110000.000Z-SDAQ-CAMERA.hdf5"
#    (29 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T120000.000Z-SDAQ-CAMERA.hdf5"
#    (30 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T120000.000Z-SDAQ-PMTSPEC.hdf5"
#    (31 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T130000.000Z-SDAQ-PMTSPEC.hdf5"
#    (32 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T130000.000Z-SDAQ-CAMERA.hdf5"
#    (33 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T140000.000Z-SDAQ-PMTSPEC.hdf5"
#    (34 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T140000.000Z-SDAQ-CAMERA.hdf5"
#    (35 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T150000.000Z-SDAQ-PMTSPEC.hdf5"
#    (36 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T150000.000Z-SDAQ-CAMERA.hdf5"
#    (37 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T160000.000Z-SDAQ-CAMERA.hdf5"
#    (38 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T160000.000Z-SDAQ-PMTSPEC.hdf5"
#    (39 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T170000.000Z-SDAQ-PMTSPEC.hdf5"
#    (40 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T170000.000Z-SDAQ-CAMERA.hdf5"
#    (41 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T180000.000Z-SDAQ-PMTSPEC.hdf5"
#    (42 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T180000.000Z-SDAQ-CAMERA.hdf5"
#    (43 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T190000.000Z-SDAQ-CAMERA.hdf5"
#    (44 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T190000.000Z-SDAQ-PMTSPEC.hdf5"
#    (45 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T200000.000Z-SDAQ-CAMERA.hdf5"
#    (46 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T200000.000Z-SDAQ-PMTSPEC.hdf5"
#    (47 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T210000.000Z-SDAQ-CAMERA.hdf5"
#    (48 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T210000.000Z-SDAQ-PMTSPEC.hdf5"
#    (49 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T220000.000Z-SDAQ-PMTSPEC.hdf5"
#    (50 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T220000.000Z-SDAQ-CAMERA.hdf5"
#    (51 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T230000.000Z-SDAQ-PMTSPEC.hdf5"
#    (52 of 52) Downloading file: "TUMPMTSPECTROMETER001_20210502T230000.000Z-SDAQ-CAMERA.hdf5"
# 52 files (3.4 GB) downloaded
# Total Download Time: 12 minutes

# %%
#first we need a list of file name as input
file_name_list = ["TUMPMTSPECTROMETER001_20210502T000000.000Z-SDAQ-MINISPEC.hdf5",
                 "TUMPMTSPECTROMETER001_20210501T000000.000Z-SDAQ-MINISPEC.hdf5"]
multi_pmt_minispec_run = minispec.MultiFileHandler(file_name_list)

print(multi_pmt_minispec_run.module_name)
print(multi_pmt_minispec_run.ADC_counts_dict_0)
print(multi_pmt_minispec_run.start_time)
print(multi_pmt_minispec_run.end_time)
# Out:
# /Users/ruohanli/Documents/Programs/strawb_package/raw_module_data/TUMPMTSPECTROMETER001_20210502T000000.000Z-SDAQ-MINISPEC.hdf5
# PMTSPECTROMETER001
# 20210502T000000
# /Users/ruohanli/Documents/Programs/strawb_package/raw_module_data/TUMPMTSPECTROMETER001_20210501T000000.000Z-SDAQ-MINISPEC.hdf5
# PMTSPECTROMETER001
# 20210501T000000
# /Users/ruohanli/Documents/Programs/strawb_package/raw_module_data/TUMPMTSPECTROMETER001_20210502T000000.000Z-SDAQ-MINISPEC.hdf5
# PMTSPECTROMETER001
# 20210502T000000
# /Users/ruohanli/Documents/Programs/strawb_package/raw_module_data/TUMPMTSPECTROMETER001_20210501T000000.000Z-SDAQ-MINISPEC.hdf5
# PMTSPECTROMETER001
# 20210501T000000
# /Users/ruohanli/Documents/Programs/strawb_package/raw_module_data/TUMPMTSPECTROMETER001_20210502T000000.000Z-SDAQ-MINISPEC.hdf5
# PMTSPECTROMETER001
# 20210502T000000
# /Users/ruohanli/Documents/Programs/strawb_package/raw_module_data/TUMPMTSPECTROMETER001_20210501T000000.000Z-SDAQ-MINISPEC.hdf5
# PMTSPECTROMETER001
# 20210501T000000
# PMTSPECTROMETER001
# {'20210502T000000': array([[15946, 12101, 12475, ...,  2085,  2093,  2086],
#        [15951, 12096, 12440, ...,  2086,  2091,  2085],
#        [15952, 12097, 12513, ...,  2082,  2094,  2086],
#        ...,
#        [15931, 11873, 12309, ...,  2088,  2093,  2086],
#        [15931, 11865, 12261, ...,  2086,  2092,  2083],
#        [15926, 11892, 12189, ...,  2084,  2092,  2086]], dtype=uint16), '20210501T000000': array([[15950, 11976, 12353, ...,  2085,  2090,  2085],
#        [15936, 11984, 12412, ...,  2086,  2092,  2086],
#        [15943, 12045, 12456, ...,  2085,  2093,  2085],
#        ...,
#        [15942, 12018, 12575, ...,  2084,  2093,  2083],
#        [15953, 12090, 12476, ...,  2085,  2093,  2088],
#        [15944, 12064, 12463, ...,  2086,  2093,  2088]], dtype=uint16)}
# 2021-05-01 23:58:59.218292
# None
